# %% [markdown]
# <a href="https://colab.research.google.com/github/Sakib56/TTDS-G35-CW3/blob/main/GPT-6-J.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GPT-J-6B Inference Demo
#
# <a href="http://colab.research.google.com/github/kingoflolz/mesh-transformer-jax/blob/master/colab_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# This notebook demonstrates how to run the [GPT-J-6B model](https://github.com/kingoflolz/mesh-transformer-jax/#GPT-J-6B). See the link for more details about the model, including evaluation metrics and credits.

# %% [markdown]
# ## Install Dependencies
#
# First we download the model and install some dependencies. This step takes at least 5 minutes (possibly longer depending on server load).
#
# !!! **Make sure you are using a TPU runtime!** !!!

# %%
# !ls
# Out:
# sample_data

# %%
# xaa
# !time wget --output-document=xaa "https://onedrive.live.com/download?cid=AA79155FB3E6C964&resid=AA79155FB3E6C964%21212&authkey=ANyxbU1jlitY56E"
#xab
# !time wget --output-document=xab -c "https://onedrive.live.com/download?cid=F4FBC1205A1DB176&resid=F4FBC1205A1DB176%21296&authkey=ACk_9aRWxhnGrsQ"

# !cat xab >> xaa

# !mv xaa step_383500_slim.tar.zstd

# !apt install zstd

# the "slim" version contain only bf16 weights and no optimizer parameters, which minimizes bandwidth and memory

# !time tar -I zstd -xf step_383500_slim.tar.zstd

# !git clone https://github.com/kingoflolz/mesh-transformer-jax.git
# !pip install -r mesh-transformer-jax/requirements.txt --use-deprecated=legacy-resolver

# jax 0.2.12 is required due to a regression with xmap in 0.2.13
# !pip install mesh-transformer-jax/ jax==0.2.12 tensorflow==2.5.0 --use-deprecated=legacy-resolver
# Out:
# --2022-02-25 15:02:50--  https://onedrive.live.com/download?cid=AA79155FB3E6C964&resid=AA79155FB3E6C964%21212&authkey=ANyxbU1jlitY56E
# Resolving onedrive.live.com (onedrive.live.com)... 13.107.43.13
# Connecting to onedrive.live.com (onedrive.live.com)|13.107.43.13|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://qrq2pq.am.files.1drv.com/y4mcQCN71jxGM-dcu5zB8U-cMmm6HWu7ko3Rj-eCK_hn6HZxhwP3mkxCoifFPxr9k9ghR4GoUkX7ei4eWmqK0iuFpeHUOYpqSaflxeeWWUI9-ru6e825ROl1zIonuqVSbby7f8pJeExMZXKcjvwkCs_r6fCiG3WB9Qho940vaXP41Ac9J3mXscqwbrfiwYUh67aM4YR7bDlsWdzsZjULHi76A/xaa?download&psid=1 [following]
# --2022-02-25 15:02:51--  https://qrq2pq.am.files.1drv.com/y4mcQCN71jxGM-dcu5zB8U-cMmm6HWu7ko3Rj-eCK_hn6HZxhwP3mkxCoifFPxr9k9ghR4GoUkX7ei4eWmqK0iuFpeHUOYpqSaflxeeWWUI9-ru6e825ROl1zIonuqVSbby7f8pJeExMZXKcjvwkCs_r6fCiG3WB9Qho940vaXP41Ac9J3mXscqwbrfiwYUh67aM4YR7bDlsWdzsZjULHi76A/xaa?download&psid=1
# Resolving qrq2pq.am.files.1drv.com (qrq2pq.am.files.1drv.com)... 13.107.43.12
# Connecting to qrq2pq.am.files.1drv.com (qrq2pq.am.files.1drv.com)|13.107.43.12|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4707356162 (4.4G) [application/octet-stream]
# Saving to: ‘xaa’
#
# xaa                 100%[===================>]   4.38G  30.5MB/s    in 2m 19s
#
# 2022-02-25 15:05:11 (32.3 MB/s) - ‘xaa’ saved [4707356162/4707356162]
#
#
# real	2m20.523s
# user	0m2.536s
# sys	0m12.057s
# --2022-02-25 15:05:11--  https://onedrive.live.com/download?cid=F4FBC1205A1DB176&resid=F4FBC1205A1DB176%21296&authkey=ACk_9aRWxhnGrsQ
# Resolving onedrive.live.com (onedrive.live.com)... 13.107.43.13
# Connecting to onedrive.live.com (onedrive.live.com)|13.107.43.13|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://31dqfg.am.files.1drv.com/y4m_sdA75QC56UhnYQ8BPdzteF5U6gZRbUK0D8YN2EHw5p1N1_HodZhzQ500PsIVkmuNvQIkQdq7W2NoX8nwhoOCNxdSggDng_Z66OqPIkugsXfN4A9eNo4rfygQgwi55hM_u8kwgbqSubuBgTGwBrdS0MY6HSh6lHy2ufXzuCCjLIVH3txb8d_Yf-VLsmad5-ZNaw8g_ipuvmBdQCALZcY7Q/xab?download&psid=1 [following]
# --2022-02-25 15:05:12--  https://31dqfg.am.files.1drv.com/y4m_sdA75QC56UhnYQ8BPdzteF5U6gZRbUK0D8YN2EHw5p1N1_HodZhzQ500PsIVkmuNvQIkQdq7W2NoX8nwhoOCNxdSggDng_Z66OqPIkugsXfN4A9eNo4rfygQgwi55hM_u8kwgbqSubuBgTGwBrdS0MY6HSh6lHy2ufXzuCCjLIVH3txb8d_Yf-VLsmad5-ZNaw8g_ipuvmBdQCALZcY7Q/xab?download&psid=1
# Resolving 31dqfg.am.files.1drv.com (31dqfg.am.files.1drv.com)... 13.107.43.12
# Connecting to 31dqfg.am.files.1drv.com (31dqfg.am.files.1drv.com)|13.107.43.12|:443... connected.
# HTTP request sent, awaiting response... 416 Requested Range Not Satisfiable
#
#     The file is already fully retrieved; nothing to do.
#
#
# real	0m1.574s
# user	0m0.015s
# sys	0m0.002s
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# zstd is already the newest version (1.3.3+dfsg-2ubuntu1.2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-470
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.
#
# real	0m48.197s
# user	0m30.852s
# sys	0m27.851s
# fatal: destination path 'mesh-transformer-jax' already exists and is not an empty directory.
# Collecting git+https://github.com/EleutherAI/lm-evaluation-harness/ (from -r mesh-transformer-jax/requirements.txt (line 9))
#   Cloning https://github.com/EleutherAI/lm-evaluation-harness/ to /tmp/pip-req-build-olb09o2m
#   Running command git clone -q https://github.com/EleutherAI/lm-evaluation-harness/ /tmp/pip-req-build-olb09o2m
# Collecting numpy~=1.19.5
#   Using cached numpy-1.19.5-cp37-cp37m-manylinux2010_x86_64.whl (14.8 MB)
# Requirement already satisfied: tqdm>=4.45.0 in /usr/local/lib/python3.7/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 2)) (4.62.3)
# Collecting wandb>=0.11.2
#   Using cached wandb-0.12.10-py2.py3-none-any.whl (1.7 MB)
# Collecting einops~=0.3.0
#   Using cached einops-0.3.2-py3-none-any.whl (25 kB)
# Collecting requests~=2.25.1
#   Using cached requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting fabric~=2.6.0
#   Using cached fabric-2.6.0-py2.py3-none-any.whl (53 kB)
# Collecting optax==0.0.9
#   Using cached optax-0.0.9-py3-none-any.whl (118 kB)
# Collecting dm-haiku==0.0.5
#   Using cached dm_haiku-0.0.5-py3-none-any.whl (287 kB)
# Collecting ray[default]==1.4.1
#   Using cached ray-1.4.1-cp37-cp37m-manylinux2014_x86_64.whl (51.6 MB)
# Requirement already satisfied: jax~=0.2.12 in /usr/local/lib/python3.7/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 11)) (0.2.25)
# Requirement already satisfied: Flask~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 12)) (1.1.4)
# Requirement already satisfied: cloudpickle~=1.3.0 in /usr/local/lib/python3.7/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 13)) (1.3.0)
# Collecting tensorflow-cpu~=2.6.0
#   Using cached tensorflow_cpu-2.6.3-cp37-cp37m-manylinux2010_x86_64.whl (177.8 MB)
# Collecting google-cloud-storage~=1.36.2
#   Using cached google_cloud_storage-1.36.2-py2.py3-none-any.whl (97 kB)
# Collecting transformers
#   Using cached transformers-4.16.2-py3-none-any.whl (3.5 MB)
# Requirement already satisfied: smart_open[gcs] in /usr/local/lib/python3.7/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 17)) (5.2.1)
# Collecting func_timeout
#   Using cached func_timeout-4.3.5.tar.gz (44 kB)
# Collecting ftfy
#   Using cached ftfy-6.1.1-py3-none-any.whl (53 kB)
# Collecting fastapi
#   Using cached fastapi-0.74.1-py3-none-any.whl (53 kB)
# Collecting uvicorn
#   Using cached uvicorn-0.17.5-py3-none-any.whl (53 kB)
# Collecting lm_dataformat
#   Using cached lm_dataformat-0.0.20-py3-none-any.whl (5.8 kB)
# Collecting pathy
#   Using cached pathy-0.6.1-py3-none-any.whl (42 kB)
# Collecting black
#   Using cached black-22.1.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
# Collecting best_download==0.0.9
#   Using cached best_download-0.0.9-py3-none-any.whl (6.5 kB)
# Collecting datasets==1.15.1
#   Using cached datasets-1.15.1-py3-none-any.whl (290 kB)
# Requirement already satisfied: click>=7.1 in /usr/local/lib/python3.7/dist-packages (from lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (7.1.2)
# Requirement already satisfied: scikit-learn>=0.24.1 in /usr/local/lib/python3.7/dist-packages (from lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.0.2)
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.7/dist-packages (from lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.10.0+cu111)
# Collecting sqlitedict==1.6.0
#   Using cached sqlitedict-1.6.0.tar.gz (29 kB)
# Collecting pytablewriter==0.58.0
#   Using cached pytablewriter-0.58.0-py3-none-any.whl (96 kB)
# Collecting sacrebleu==1.5.0
#   Using cached sacrebleu-1.5.0-py3-none-any.whl (65 kB)
# Collecting rouge-score==0.0.4
#   Using cached rouge_score-0.0.4-py2.py3-none-any.whl (22 kB)
# Collecting bleurt@ https://github.com/google-research/bleurt/archive/b610120347ef22b494b6d69b4316e303f5932516.zip#egg=bleurt
#   Using cached https://github.com/google-research/bleurt/archive/b610120347ef22b494b6d69b4316e303f5932516.zip
# Collecting pycountry==20.7.3
#   Using cached pycountry-20.7.3.tar.gz (10.1 MB)
# Collecting numexpr==2.7.2
#   Using cached numexpr-2.7.2-cp37-cp37m-manylinux2010_x86_64.whl (471 kB)
# Collecting pytest==6.2.3
#   Using cached pytest-6.2.3-py3-none-any.whl (280 kB)
# Collecting pybind11==2.6.2
#   Using cached pybind11-2.6.2-py2.py3-none-any.whl (191 kB)
# Collecting tqdm-multiprocess==0.0.11
#   Using cached tqdm_multiprocess-0.0.11-py3-none-any.whl (9.8 kB)
# Collecting zstandard==0.15.2
#   Using cached zstandard-0.15.2-cp37-cp37m-manylinux2014_x86_64.whl (2.2 MB)
# Collecting jsonlines==2.0.0
#   Using cached jsonlines-2.0.0-py3-none-any.whl (6.3 kB)
# Collecting mock==4.0.3
#   Using cached mock-4.0.3-py3-none-any.whl (28 kB)
# Collecting openai==0.6.4
#   Using cached openai-0.6.4.tar.gz (159 kB)
# Requirement already satisfied: jieba==0.42.1 in /usr/local/lib/python3.7/dist-packages (from lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.42.1)
# Collecting nagisa==0.2.7
#   Using cached nagisa-0.2.7-cp37-cp37m-manylinux1_x86_64.whl (21.5 MB)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.11.2->-r mesh-transformer-jax/requirements.txt (line 3)) (2.8.2)
# Collecting pathtools
#   Using cached pathtools-0.1.2.tar.gz (11 kB)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.11.2->-r mesh-transformer-jax/requirements.txt (line 3)) (2.3)
# Collecting GitPython>=1.0.0
#   Using cached GitPython-3.1.27-py3-none-any.whl (181 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb>=0.11.2->-r mesh-transformer-jax/requirements.txt (line 3)) (3.13)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.11.2->-r mesh-transformer-jax/requirements.txt (line 3)) (1.15.0)
# Collecting shortuuid>=0.5.0
#   Using cached shortuuid-1.0.8-py3-none-any.whl (9.5 kB)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.11.2->-r mesh-transformer-jax/requirements.txt (line 3)) (5.4.8)
# Collecting docker-pycreds>=0.4.0
#   Using cached docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.11.2->-r mesh-transformer-jax/requirements.txt (line 3)) (3.17.3)
# Collecting sentry-sdk>=1.0.0
#   Using cached sentry_sdk-1.5.6-py2.py3-none-any.whl (144 kB)
# Collecting yaspin>=1.0.0
#   Using cached yaspin-2.1.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests~=2.25.1->-r mesh-transformer-jax/requirements.txt (line 5)) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests~=2.25.1->-r mesh-transformer-jax/requirements.txt (line 5)) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests~=2.25.1->-r mesh-transformer-jax/requirements.txt (line 5)) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests~=2.25.1->-r mesh-transformer-jax/requirements.txt (line 5)) (2.10)
# Collecting pathlib2
#   Using cached pathlib2-2.3.7.post1-py2.py3-none-any.whl (18 kB)
# Collecting paramiko>=2.4
#   Using cached paramiko-2.9.2-py2.py3-none-any.whl (210 kB)
# Collecting invoke<2.0,>=1.3
#   Using cached invoke-1.6.0-py3-none-any.whl (212 kB)
# Collecting chex>=0.0.4
#   Using cached chex-0.1.1-py3-none-any.whl (70 kB)
# Requirement already satisfied: jaxlib>=0.1.37 in /usr/local/lib/python3.7/dist-packages (from optax==0.0.9->-r mesh-transformer-jax/requirements.txt (line 7)) (0.1.71+cuda111)
# Requirement already satisfied: absl-py>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from optax==0.0.9->-r mesh-transformer-jax/requirements.txt (line 7)) (1.0.0)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from dm-haiku==0.0.5->-r mesh-transformer-jax/requirements.txt (line 8)) (3.10.0.2)
# Collecting jmp>=0.0.2
#   Using cached jmp-0.0.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from dm-haiku==0.0.5->-r mesh-transformer-jax/requirements.txt (line 8)) (0.8.9)
# Collecting aiohttp-cors
#   Using cached aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: grpcio>=1.28.1 in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (1.43.0)
# Collecting py-spy>=0.2.0
#   Using cached py_spy-0.3.11-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (3.0 MB)
# Collecting opencensus
#   Using cached opencensus-0.8.0-py2.py3-none-any.whl (128 kB)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (1.0.3)
# Collecting aioredis
#   Using cached aioredis-2.0.1-py3-none-any.whl (71 kB)
# Collecting colorama
#   Using cached colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: prometheus-client>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (0.13.1)
# Collecting redis>=3.5.0
#   Using cached redis-4.1.4-py3-none-any.whl (175 kB)
# Collecting aiohttp
#   Using cached aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
# Collecting gpustat
#   Using cached gpustat-0.6.0.tar.gz (78 kB)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (4.3.3)
# Collecting pydantic>=1.8
#   Using cached pydantic-1.9.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.9 MB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (3.6.0)
# Collecting colorful; extra == "default"
#   Using cached colorful-0.5.4-py2.py3-none-any.whl (201 kB)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.7/dist-packages (from jax~=0.2.12->-r mesh-transformer-jax/requirements.txt (line 11)) (3.3.0)
# Requirement already satisfied: scipy>=1.2.1 in /usr/local/lib/python3.7/dist-packages (from jax~=0.2.12->-r mesh-transformer-jax/requirements.txt (line 11)) (1.4.1)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask~=1.1.2->-r mesh-transformer-jax/requirements.txt (line 12)) (2.11.3)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask~=1.1.2->-r mesh-transformer-jax/requirements.txt (line 12)) (1.1.0)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask~=1.1.2->-r mesh-transformer-jax/requirements.txt (line 12)) (1.0.1)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (0.37.1)
# Collecting keras<2.7,>=2.6.0
#   Using cached keras-2.6.0-py2.py3-none-any.whl (1.3 MB)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (0.2.0)
# Collecting gast==0.4.0
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (1.1.2)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (1.6.3)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (3.1.0)
# Collecting flatbuffers~=1.12.0
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (1.1.0)
# Collecting wrapt~=1.12.1
#   Using cached wrapt-1.12.1.tar.gz (27 kB)
# Collecting clang~=5.0
#   Using cached clang-5.0.tar.gz (30 kB)
# Collecting tensorboard<2.7,>=2.6.0
#   Using cached tensorboard-2.6.0-py3-none-any.whl (5.6 MB)
# Collecting tensorflow-estimator<2.7,>=2.6.0
#   Using cached tensorflow_estimator-2.6.0-py2.py3-none-any.whl (462 kB)
# Collecting google-cloud-core<2.0dev,>=1.4.1
#   Using cached google_cloud_core-1.7.2-py2.py3-none-any.whl (28 kB)
# Collecting google-resumable-media<2.0dev,>=1.2.0
#   Using cached google_resumable_media-1.3.3-py2.py3-none-any.whl (75 kB)
# Requirement already satisfied: google-auth<2.0dev,>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage~=1.36.2->-r mesh-transformer-jax/requirements.txt (line 15)) (1.35.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers->-r mesh-transformer-jax/requirements.txt (line 16)) (2019.12.20)
# Collecting sacremoses
#   Using cached sacremoses-0.0.47-py2.py3-none-any.whl (895 kB)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers->-r mesh-transformer-jax/requirements.txt (line 16)) (4.11.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers->-r mesh-transformer-jax/requirements.txt (line 16)) (21.3)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Using cached huggingface_hub-0.4.0-py3-none-any.whl (67 kB)
# Collecting tokenizers!=0.11.3,>=0.10.1
#   Using cached tokenizers-0.11.5-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.8 MB)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.7/dist-packages (from ftfy->-r mesh-transformer-jax/requirements.txt (line 19)) (0.2.5)
# Collecting starlette==0.17.1
#   Using cached starlette-0.17.1-py3-none-any.whl (58 kB)
# Collecting asgiref>=3.4.0
#   Using cached asgiref-3.5.0-py3-none-any.whl (22 kB)
# Collecting h11>=0.8
#   Using cached h11-0.13.0-py3-none-any.whl (58 kB)
# Collecting ujson
#   Using cached ujson-5.1.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43 kB)
# Collecting typer<1.0.0,>=0.3.0
#   Using cached typer-0.4.0-py3-none-any.whl (27 kB)
# Collecting platformdirs>=2
#   Using cached platformdirs-2.5.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from black->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (2.0.1)
# Collecting pathspec>=0.9.0
#   Using cached pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Collecting typed-ast>=1.4.2; python_version < "3.8" and implementation_name == "cpython"
#   Using cached typed_ast-1.5.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (843 kB)
# Collecting mypy-extensions>=0.4.3
#   Downloading mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Collecting rehash
#   Using cached rehash-1.0.0-py2.py3-none-any.whl (8.7 kB)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets==1.15.1->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.3.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets==1.15.1->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.3.5)
# Collecting fsspec[http]>=2021.05.0
#   Using cached fsspec-2022.2.0-py3-none-any.whl (134 kB)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets==1.15.1->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.70.12.2)
# Requirement already satisfied: pyarrow!=4.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets==1.15.1->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (6.0.1)
# Collecting xxhash
#   Using cached xxhash-3.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24.1->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24.1->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (3.1.0)
# Collecting tcolorpy<1,>=0.0.5
#   Using cached tcolorpy-0.1.1-py3-none-any.whl (8.0 kB)
# Collecting mbstrdecoder<2,>=1.0.0
#   Using cached mbstrdecoder-1.1.0-py3-none-any.whl (7.8 kB)
# Collecting msgfy<1,>=0.1.0
#   Using cached msgfy-0.2.0-py3-none-any.whl (4.3 kB)
# Collecting DataProperty<2,>=0.50.0
#   Using cached DataProperty-0.54.2-py3-none-any.whl (26 kB)
# Collecting pathvalidate<3,>=2.3.0
#   Using cached pathvalidate-2.5.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: setuptools>=38.3.0 in /usr/local/lib/python3.7/dist-packages (from pytablewriter==0.58.0->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (57.4.0)
# Collecting tabledata<2,>=1.1.3
#   Using cached tabledata-1.3.0-py3-none-any.whl (11 kB)
# Collecting typepy[datetime]<2,>=1.1.1
#   Using cached typepy-1.3.0-py3-none-any.whl (31 kB)
# Collecting portalocker
#   Using cached portalocker-2.4.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from rouge-score==0.0.4->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (3.2.5)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (from bleurt@ https://github.com/google-research/bleurt/archive/b610120347ef22b494b6d69b4316e303f5932516.zip#egg=bleurt->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (2.8.0)
# Collecting tf-slim>=1.1
#   Using cached tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
# Collecting sentencepiece
#   Using cached sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from pytest==6.2.3->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (21.4.0)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.7/dist-packages (from pytest==6.2.3->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.1.1)
# Requirement already satisfied: py>=1.8.2 in /usr/local/lib/python3.7/dist-packages (from pytest==6.2.3->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.11.0)
# Collecting toml
#   Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting pluggy<1.0.0a1,>=0.12
#   Using cached pluggy-0.13.1-py2.py3-none-any.whl (18 kB)
# Collecting DyNet
#   Using cached dyNET-2.1.2-cp37-cp37m-manylinux1_x86_64.whl (4.4 MB)
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.9-py3-none-any.whl (63 kB)
# Collecting bcrypt>=3.1.3
#   Using cached bcrypt-3.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (61 kB)
# Collecting cryptography>=2.5
#   Using cached cryptography-36.0.1-cp36-abi3-manylinux_2_24_x86_64.whl (3.6 MB)
# Collecting pynacl>=1.0.1
#   Using cached PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from chex>=0.0.4->optax==0.0.9->-r mesh-transformer-jax/requirements.txt (line 7)) (0.11.2)
# Requirement already satisfied: dm-tree>=0.1.5 in /usr/local/lib/python3.7/dist-packages (from chex>=0.0.4->optax==0.0.9->-r mesh-transformer-jax/requirements.txt (line 7)) (0.1.6)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from opencensus->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (1.26.3)
# Collecting opencensus-context==0.1.2
#   Downloading opencensus_context-0.1.2-py2.py3-none-any.whl (4.4 kB)
# Collecting async-timeout
#   Using cached async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting deprecated>=1.2.3
#   Using cached Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (2.0.12)
# Collecting multidict<7.0,>=4.5
#   Using cached multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
# Collecting frozenlist>=1.1.1
#   Using cached frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
# Collecting yarl<2.0,>=1.0
#   Using cached yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
# Collecting asynctest==0.13.0; python_version < "3.8"
#   Using cached asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting aiosignal>=1.1.2
#   Using cached aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: nvidia-ml-py3>=7.352.0 in /usr/local/lib/python3.7/dist-packages (from gpustat->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (7.352.0)
# Collecting blessings>=1.6
#   Downloading blessings-1.7-py3-none-any.whl (18 kB)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (0.18.1)
# Requirement already satisfied: importlib-resources>=1.4.0; python_version < "3.9" in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (5.4.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask~=1.1.2->-r mesh-transformer-jax/requirements.txt (line 12)) (2.0.1)
# Requirement already satisfied: cached-property; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from h5py~=3.1.0->tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (1.5.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (3.3.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (1.8.1)
# Collecting google-crc32c<2.0dev,>=1.0; python_version >= "3.5"
#   Using cached google_crc32c-1.3.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38 kB)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage~=1.36.2->-r mesh-transformer-jax/requirements.txt (line 15)) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage~=1.36.2->-r mesh-transformer-jax/requirements.txt (line 15)) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage~=1.36.2->-r mesh-transformer-jax/requirements.txt (line 15)) (0.2.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers->-r mesh-transformer-jax/requirements.txt (line 16)) (3.7.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers->-r mesh-transformer-jax/requirements.txt (line 16)) (3.0.7)
# Collecting anyio<4,>=3.0.0
#   Using cached anyio-3.5.0-py3-none-any.whl (79 kB)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets==1.15.1->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (2018.9)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->bleurt@ https://github.com/google-research/bleurt/archive/b610120347ef22b494b6d69b4316e303f5932516.zip#egg=bleurt->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (13.0.0)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 7.0 MB/s
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->bleurt@ https://github.com/google-research/bleurt/archive/b610120347ef22b494b6d69b4316e303f5932516.zip#egg=bleurt->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.24.0)
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from DyNet->nagisa==0.2.7->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.29.28)
# Collecting smmap<6,>=3.0.1
#   Using cached smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: cffi>=1.1 in /usr/local/lib/python3.7/dist-packages (from bcrypt>=3.1.3->paramiko>=2.4->fabric~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 6)) (1.15.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3.0.0,>=1.0.0; python_version >= "3.6"->opencensus->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (1.54.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.7,>=2.6.0->tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (1.3.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2.0dev,>=1.11.0->google-cloud-storage~=1.36.2->-r mesh-transformer-jax/requirements.txt (line 15)) (0.4.8)
# Collecting sniffio>=1.1
#   Using cached sniffio-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko>=2.4->fabric~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 6)) (2.21)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.7,>=2.6.0->tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (3.2.0)
# Building wheels for collected packages: func-timeout, lm-eval, sqlitedict, bleurt, pycountry, openai, pathtools, gpustat, wrapt, clang
#   Building wheel for func-timeout (setup.py) ... done
#   Created wheel for func-timeout: filename=func_timeout-4.3.5-py3-none-any.whl size=15098 sha256=41481203893499ef59720f8a35aeb8cad7cb03e525fb8b3f41ebd01587f4322b
#   Stored in directory: /root/.cache/pip/wheels/68/b5/a5/67c4364c354e141f5a1bd3ec568126f77877ab7554cf5af8cb
#   Building wheel for lm-eval (setup.py) ... done
#   Created wheel for lm-eval: filename=lm_eval-0.1.0-py3-none-any.whl size=120672 sha256=5f4184deab6a1534b86426251200221faa8e137ca971d6790f0993fcdcfb0e65
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hr0kquh8/wheels/35/22/ec/71da337686fde904ec27f675d1bf73c4f253c48a6174d822b0
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-1.6.0-py3-none-any.whl size=14712 sha256=45dd64b1c2fa48f09b5e4773f54cc46026b0632a7683d4b810e15df8debb3f56
#   Stored in directory: /root/.cache/pip/wheels/58/dd/2c/0a57aadf6a7f26bec0af66d742c50af74d11967780f0bb7a7d
#   Building wheel for bleurt (setup.py) ... done
#   Created wheel for bleurt: filename=BLEURT-0.0.2-py3-none-any.whl size=16454023 sha256=e4881bd9e9b18d4675c7d301dc60c982c766999777eda09cef3481b8be6ced8f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hr0kquh8/wheels/e4/25/b5/d3b124fc2717a794a8dcb176fac9a01bec46e9f3ff0dbf5d37
#   Building wheel for pycountry (setup.py) ... done
#   Created wheel for pycountry: filename=pycountry-20.7.3-py2.py3-none-any.whl size=10746882 sha256=c5df1f432ffd95704e58326208fccd19844a59bba778184f23cff694f2b7e18b
#   Stored in directory: /root/.cache/pip/wheels/57/e8/3f/120ccc1ff7541c108bc5d656e2a14c39da0d824653b62284c6
#   Building wheel for openai (setup.py) ... done
#   Created wheel for openai: filename=openai-0.6.4-py3-none-any.whl size=172215 sha256=0140450613dbef274caab38e639de40fa9bf20603a9fffe16ab9285345faa5ec
#   Stored in directory: /root/.cache/pip/wheels/54/c4/02/aa519fe2aaf97a9bba197a8585182c8c07802760351afdb64a
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=9ebaac4819a7c45db64536b2db646b982abfb5c59d5536c7fe99ab8797572bbd
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
#   Building wheel for gpustat (setup.py) ... done
#   Created wheel for gpustat: filename=gpustat-0.6.0-py3-none-any.whl size=12617 sha256=cf1f11da13ca013496ffd1e9cdae6f0b21634018a70d2f3a1ce8679ae09801c1
#   Stored in directory: /root/.cache/pip/wheels/e6/67/af/f1ad15974b8fd95f59a63dbf854483ebe5c7a46a93930798b8
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp37-cp37m-linux_x86_64.whl size=68692 sha256=314bfe1d1a7be2aad8918b4cd3897fe7445c1dc2c498b9c71fea21a42cf87f10
#   Stored in directory: /root/.cache/pip/wheels/62/76/4c/aa25851149f3f6d9785f6c869387ad82b3fd37582fa8147ac6
#   Building wheel for clang (setup.py) ... done
#   Created wheel for clang: filename=clang-5.0-py3-none-any.whl size=30694 sha256=79cbca07b856a7030ba3e2aee10f0d9d00d085c899a4ad8fd363d14bc2a8e9ac
#   Stored in directory: /root/.cache/pip/wheels/98/91/04/971b4c587cf47ae952b108949b46926f426c02832d120a082a
# Successfully built func-timeout lm-eval sqlitedict bleurt pycountry openai pathtools gpustat wrapt clang
# Installing collected packages: numpy, pathtools, smmap, gitdb, GitPython, shortuuid, docker-pycreds, requests, sentry-sdk, yaspin, wandb, einops, pathlib2, bcrypt, cryptography, pynacl, paramiko, invoke, fabric, chex, optax, jmp, dm-haiku, multidict, frozenlist, yarl, asynctest, aiosignal, async-timeout, aiohttp, aiohttp-cors, py-spy, opencensus-context, opencensus, aioredis, colorama, wrapt, deprecated, redis, blessings, gpustat, pydantic, colorful, ray, keras, gast, flatbuffers, clang, tensorboard, tensorflow-estimator, tensorflow-cpu, google-cloud-core, google-crc32c, google-resumable-media, google-cloud-storage, sacremoses, huggingface-hub, tokenizers, transformers, func-timeout, ftfy, sniffio, anyio, starlette, fastapi, asgiref, h11, uvicorn, jsonlines, ujson, zstandard, lm-dataformat, typer, pathy, platformdirs, pathspec, typed-ast, mypy-extensions, black, rehash, best-download, fsspec, xxhash, datasets, sqlitedict, tcolorpy, mbstrdecoder, msgfy, typepy, DataProperty, pathvalidate, tabledata, pytablewriter, portalocker, sacrebleu, rouge-score, tf-slim, sentencepiece, bleurt, pycountry, numexpr, toml, pluggy, pytest, pybind11, tqdm-multiprocess, mock, openai, DyNet, nagisa, lm-eval, tf-estimator-nightly
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.5
#     Uninstalling numpy-1.21.5:
#       Successfully uninstalled numpy-1.21.5
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.13.3
#     Uninstalling wrapt-1.13.3:
#       Successfully uninstalled wrapt-1.13.3
#   Attempting uninstall: keras
#     Found existing installation: keras 2.8.0
#     Uninstalling keras-2.8.0:
#       Successfully uninstalled keras-2.8.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 2.0
#     Uninstalling flatbuffers-2.0:
#       Successfully uninstalled flatbuffers-2.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: google-cloud-core
#     Found existing installation: google-cloud-core 1.0.3
#     Uninstalling google-cloud-core-1.0.3:
#       Successfully uninstalled google-cloud-core-1.0.3
#   Attempting uninstall: google-resumable-media
#     Found existing installation: google-resumable-media 0.4.1
#     Uninstalling google-resumable-media-0.4.1:
#       Successfully uninstalled google-resumable-media-0.4.1
#   Attempting uninstall: google-cloud-storage
#     Found existing installation: google-cloud-storage 1.18.1
#     Uninstalling google-cloud-storage-1.18.1:
#       Successfully uninstalled google-cloud-storage-1.18.1
#   Attempting uninstall: numexpr
#     Found existing installation: numexpr 2.8.1
#     Uninstalling numexpr-2.8.1:
#       Successfully uninstalled numexpr-2.8.1
#   Attempting uninstall: pluggy
#     Found existing installation: pluggy 0.7.1
#     Uninstalling pluggy-0.7.1:
#       Successfully uninstalled pluggy-0.7.1
#   Attempting uninstall: pytest
#     Found existing installation: pytest 3.6.4
#     Uninstalling pytest-3.6.4:
#       Successfully uninstalled pytest-3.6.4
# ERROR: pip's legacy dependency resolver does not consider dependency conflicts when selecting packages. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0 requires keras<2.9,>=2.8.0rc0, but you'll have keras 2.6.0 which is incompatible.
# tensorflow 2.8.0 requires numpy>=1.20, but you'll have numpy 1.19.5 which is incompatible.
# tensorflow 2.8.0 requires tensorboard<2.9,>=2.8, but you'll have tensorboard 2.6.0 which is incompatible.
# google-colab 1.0.0 requires requests~=2.23.0, but you'll have requests 2.25.1 which is incompatible.
# google-cloud-bigquery 1.21.0 requires google-resumable-media!=0.4.0,<0.5.0dev,>=0.3.1, but you'll have google-resumable-media 1.3.3 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# tensorflow-cpu 2.6.3 requires absl-py~=0.10, but you'll have absl-py 1.0.0 which is incompatible.
# transformers 4.16.2 requires pyyaml>=5.1, but you'll have pyyaml 3.13 which is incompatible.
# black 22.1.0 requires click>=8.0.0, but you'll have click 7.1.2 which is incompatible.
# Successfully installed DataProperty-0.54.2 DyNet-2.1.2 GitPython-3.1.27 aiohttp-3.8.1 aiohttp-cors-0.7.0 aioredis-2.0.1 aiosignal-1.2.0 anyio-3.5.0 asgiref-3.5.0 async-timeout-4.0.2 asynctest-0.13.0 bcrypt-3.2.0 best-download-0.0.9 black-22.1.0 blessings-1.7 bleurt-0.0.2 chex-0.1.1 clang-5.0 colorama-0.4.4 colorful-0.5.4 cryptography-36.0.1 datasets-1.15.1 deprecated-1.2.13 dm-haiku-0.0.5 docker-pycreds-0.4.0 einops-0.3.2 fabric-2.6.0 fastapi-0.74.1 flatbuffers-1.12 frozenlist-1.3.0 fsspec-2022.2.0 ftfy-6.1.1 func-timeout-4.3.5 gast-0.4.0 gitdb-4.0.9 google-cloud-core-1.7.2 google-cloud-storage-1.36.2 google-crc32c-1.3.0 google-resumable-media-1.3.3 gpustat-0.6.0 h11-0.13.0 huggingface-hub-0.4.0 invoke-1.6.0 jmp-0.0.2 jsonlines-2.0.0 keras-2.6.0 lm-dataformat-0.0.20 lm-eval-0.1.0 mbstrdecoder-1.1.0 mock-4.0.3 msgfy-0.2.0 multidict-6.0.2 mypy-extensions-0.4.3 nagisa-0.2.7 numexpr-2.7.2 numpy-1.19.5 openai-0.6.4 opencensus-0.8.0 opencensus-context-0.1.2 optax-0.0.9 paramiko-2.9.2 pathlib2-2.3.7.post1 pathspec-0.9.0 pathtools-0.1.2 pathvalidate-2.5.0 pathy-0.6.1 platformdirs-2.5.1 pluggy-0.13.1 portalocker-2.4.0 py-spy-0.3.11 pybind11-2.6.2 pycountry-20.7.3 pydantic-1.9.0 pynacl-1.5.0 pytablewriter-0.58.0 pytest-6.2.3 ray-1.4.1 redis-4.1.4 rehash-1.0.0 requests-2.25.1 rouge-score-0.0.4 sacrebleu-1.5.0 sacremoses-0.0.47 sentencepiece-0.1.96 sentry-sdk-1.5.6 shortuuid-1.0.8 smmap-5.0.0 sniffio-1.2.0 sqlitedict-1.6.0 starlette-0.17.1 tabledata-1.3.0 tcolorpy-0.1.1 tensorboard-2.6.0 tensorflow-cpu-2.6.3 tensorflow-estimator-2.6.0 tf-estimator-nightly-2.8.0.dev2021122109 tf-slim-1.1.0 tokenizers-0.11.5 toml-0.10.2 tqdm-multiprocess-0.0.11 transformers-4.16.2 typed-ast-1.5.2 typepy-1.3.0 typer-0.4.0 ujson-5.1.0 uvicorn-0.17.5 wandb-0.12.10 wrapt-1.12.1 xxhash-3.0.0 yarl-1.7.2 yaspin-2.1.0 zstandard-0.15.2
# Processing ./mesh-transformer-jax
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# Collecting jax==0.2.12
#   Using cached jax-0.2.12.tar.gz (590 kB)
# Collecting tensorflow==2.5.0
#   Using cached tensorflow-2.5.0-cp37-cp37m-manylinux2010_x86_64.whl (454.3 MB)
# Requirement already satisfied: numpy>=1.12 in /usr/local/lib/python3.7/dist-packages (from jax==0.2.12) (1.19.5)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from jax==0.2.12) (1.0.0)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.7/dist-packages (from jax==0.2.12) (3.3.0)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (1.15.0)
# Collecting keras-nightly~=2.5.0.dev
#   Downloading keras_nightly-2.5.0.dev2021032900-py2.py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 5.4 MB/s
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (1.1.2)
# Collecting typing-extensions~=3.7.4
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (0.37.1)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (1.12.1)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (3.17.3)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (1.6.3)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (1.1.0)
# Collecting grpcio~=1.34.0
#   Downloading grpcio-1.34.1-cp37-cp37m-manylinux2014_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 66.5 MB/s
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (3.1.0)
# Collecting tensorflow-estimator<2.6.0,>=2.5.0rc0
#   Downloading tensorflow_estimator-2.5.0-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 75.3 MB/s
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (0.2.0)
# Requirement already satisfied: tensorboard~=2.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (2.6.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (1.12)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (0.4.0)
# Requirement already satisfied: cached-property; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from h5py~=3.1.0->tensorflow==2.5.0) (1.5.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5.0) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5.0) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5.0) (3.3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5.0) (2.25.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5.0) (0.4.6)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5.0) (57.4.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5.0) (1.0.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5.0) (1.35.0)
# Requirement already satisfied: importlib-metadata>=4.4; python_version < "3.10" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow==2.5.0) (4.11.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (2021.10.8)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (1.24.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.0) (1.3.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0) (0.2.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4; python_version < "3.10"->markdown>=2.6.8->tensorboard~=2.5->tensorflow==2.5.0) (3.7.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.0) (3.2.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0) (0.4.8)
# Building wheels for collected packages: jax, mesh-transformer
#   Building wheel for jax (setup.py) ... done
#   Created wheel for jax: filename=jax-0.2.12-py3-none-any.whl size=682487 sha256=0e92f7de3c71477eec45f24059cbe802db8cd55d14a42d3d24431e73f94b8a8e
#   Stored in directory: /root/.cache/pip/wheels/f6/4d/e5/73eec5070b77f25664c67bd793d4eb97f41bbf9be7afafd15e
#   Building wheel for mesh-transformer (setup.py) ... done
#   Created wheel for mesh-transformer: filename=mesh_transformer-0.0.0-py3-none-any.whl size=26330 sha256=1127534982f05fe9e643c4dfbf2eb0c008b73209c85c329b2f49db326a9c630c
#   Stored in directory: /root/.cache/pip/wheels/56/bd/89/b1f6b2f3d6b938d0c5812ee97756a1afd32521bea293543863
# Successfully built jax mesh-transformer
# Installing collected packages: jax, keras-nightly, typing-extensions, grpcio, tensorflow-estimator, tensorflow, mesh-transformer
#   Attempting uninstall: jax
#     Found existing installation: jax 0.2.25
#     Uninstalling jax-0.2.25:
#       Successfully uninstalled jax-0.2.25
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Uninstalling typing-extensions-3.10.0.2:
#       Successfully uninstalled typing-extensions-3.10.0.2
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.43.0
#     Uninstalling grpcio-1.43.0:
#       Successfully uninstalled grpcio-1.43.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.6.0
#     Uninstalling tensorflow-estimator-2.6.0:
#       Successfully uninstalled tensorflow-estimator-2.6.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.8.0
#     Uninstalling tensorflow-2.8.0:
#       Successfully uninstalled tensorflow-2.8.0
# ERROR: pip's legacy dependency resolver does not consider dependency conflicts when selecting packages. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.5.0 requires absl-py~=0.10, but you'll have absl-py 1.0.0 which is incompatible.
# tensorflow-cpu 2.6.3 requires absl-py~=0.10, but you'll have absl-py 1.0.0 which is incompatible.
# tensorflow-cpu 2.6.3 requires grpcio<2.0,>=1.37.0, but you'll have grpcio 1.34.1 which is incompatible.
# tensorflow-cpu 2.6.3 requires tensorflow-estimator<2.7,>=2.6.0, but you'll have tensorflow-estimator 2.5.0 which is incompatible.
# black 22.1.0 requires click>=8.0.0, but you'll have click 7.1.2 which is incompatible.
# black 22.1.0 requires typing-extensions>=3.10.0.0; python_version < "3.10", but you'll have typing-extensions 3.7.4.3 which is incompatible.
# Successfully installed grpcio-1.34.1 jax-0.2.12 keras-nightly-2.5.0.dev2021032900 mesh-transformer-0.0.0 tensorflow-2.5.0 tensorflow-estimator-2.5.0 typing-extensions-3.7.4.3

# %%
# !apt install zstd

# the "slim" version contain only bf16 weights and no optimizer parameters, which minimizes bandwidth and memory
# !time wget -c https://www.dropbox.com/s/ple4emer6epmj6z/step_383500_slim.tar.zstd?dl=1

# !mv step_383500_slim.tar.zstd\?dl\=1 step_383500_slim.tar.zstd
# !time tar -I zstd -xf step_383500_slim.tar.zstd

# !git clone https://github.com/kingoflolz/mesh-transformer-jax.git
# !pip install -r mesh-transformer-jax/requirements.txt --use-deprecated=legacy-resolver


# jax 0.2.12 is required due to a regression with xmap in 0.2.13
# !pip install mesh-transformer-jax/ jax==0.2.12 tensorflow==2.5.0 --use-deprecated=legacy-resolver
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# zstd is already the newest version (1.3.3+dfsg-2ubuntu1.2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-470
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.
# --2022-02-25 15:11:05--  https://www.dropbox.com/s/ple4emer6epmj6z/step_383500_slim.tar.zstd?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:6018:18::a27d:312
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/ple4emer6epmj6z/step_383500_slim.tar.zstd [following]
# --2022-02-25 15:11:05--  https://www.dropbox.com/s/dl/ple4emer6epmj6z/step_383500_slim.tar.zstd
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2022-02-25 15:11:05 ERROR 404: Not Found.
#
#
# real	0m0.515s
# user	0m0.008s
# sys	0m0.003s
# mv: cannot stat 'step_383500_slim.tar.zstd?dl=1': No such file or directory
#
# real	1m14.270s
# user	0m32.314s
# sys	0m29.687s
# fatal: destination path 'mesh-transformer-jax' already exists and is not an empty directory.
# Collecting git+https://github.com/EleutherAI/lm-evaluation-harness/ (from -r mesh-transformer-jax/requirements.txt (line 9))
#   Cloning https://github.com/EleutherAI/lm-evaluation-harness/ to /tmp/pip-req-build-s_mmf11q
#   Running command git clone -q https://github.com/EleutherAI/lm-evaluation-harness/ /tmp/pip-req-build-s_mmf11q
# Requirement already satisfied (use --upgrade to upgrade): lm-eval==0.1.0 from git+https://github.com/EleutherAI/lm-evaluation-harness/ in /usr/local/lib/python3.7/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 9))
# Requirement already satisfied: numpy~=1.19.5 in /usr/local/lib/python3.7/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 1)) (1.19.5)
# Requirement already satisfied: tqdm>=4.45.0 in /usr/local/lib/python3.7/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 2)) (4.62.3)
# Requirement already satisfied: wandb>=0.11.2 in /usr/local/lib/python3.7/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 3)) (0.12.10)
# Requirement already satisfied: einops~=0.3.0 in /usr/local/lib/python3.7/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 4)) (0.3.2)
# Requirement already satisfied: requests~=2.25.1 in /usr/local/lib/python3.7/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 5)) (2.25.1)
# Requirement already satisfied: fabric~=2.6.0 in /usr/local/lib/python3.7/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 6)) (2.6.0)
# Requirement already satisfied: optax==0.0.9 in /usr/local/lib/python3.7/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 7)) (0.0.9)
# Requirement already satisfied: dm-haiku==0.0.5 in /usr/local/lib/python3.7/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 8)) (0.0.5)
# Requirement already satisfied: ray[default]==1.4.1 in /usr/local/lib/python3.7/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 10)) (1.4.1)
# Requirement already satisfied: jax~=0.2.12 in /usr/local/lib/python3.7/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 11)) (0.2.12)
# Requirement already satisfied: Flask~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 12)) (1.1.4)
# Requirement already satisfied: cloudpickle~=1.3.0 in /usr/local/lib/python3.7/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 13)) (1.3.0)
# Requirement already satisfied: tensorflow-cpu~=2.6.0 in /usr/local/lib/python3.7/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 14)) (2.6.3)
# Requirement already satisfied: google-cloud-storage~=1.36.2 in /usr/local/lib/python3.7/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 15)) (1.36.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 16)) (4.16.2)
# Requirement already satisfied: smart_open[gcs] in /usr/local/lib/python3.7/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 17)) (5.2.1)
# Requirement already satisfied: func_timeout in /usr/local/lib/python3.7/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 18)) (4.3.5)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.7/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 19)) (6.1.1)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.7/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 20)) (0.74.1)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.7/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 21)) (0.17.5)
# Requirement already satisfied: lm_dataformat in /usr/local/lib/python3.7/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 22)) (0.0.20)
# Requirement already satisfied: pathy in /usr/local/lib/python3.7/dist-packages (from -r mesh-transformer-jax/requirements.txt (line 23)) (0.6.1)
# Requirement already satisfied: black in /usr/local/lib/python3.7/dist-packages (from lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (22.1.0)
# Requirement already satisfied: best_download==0.0.9 in /usr/local/lib/python3.7/dist-packages (from lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.0.9)
# Requirement already satisfied: datasets==1.15.1 in /usr/local/lib/python3.7/dist-packages (from lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.15.1)
# Requirement already satisfied: click>=7.1 in /usr/local/lib/python3.7/dist-packages (from lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (7.1.2)
# Requirement already satisfied: scikit-learn>=0.24.1 in /usr/local/lib/python3.7/dist-packages (from lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.0.2)
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.7/dist-packages (from lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.10.0+cu111)
# Requirement already satisfied: sqlitedict==1.6.0 in /usr/local/lib/python3.7/dist-packages (from lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.6.0)
# Requirement already satisfied: pytablewriter==0.58.0 in /usr/local/lib/python3.7/dist-packages (from lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.58.0)
# Requirement already satisfied: sacrebleu==1.5.0 in /usr/local/lib/python3.7/dist-packages (from lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.5.0)
# Requirement already satisfied: rouge-score==0.0.4 in /usr/local/lib/python3.7/dist-packages (from lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.0.4)
# Requirement already satisfied: bleurt@ https://github.com/google-research/bleurt/archive/b610120347ef22b494b6d69b4316e303f5932516.zip#egg=bleurt from https://github.com/google-research/bleurt/archive/b610120347ef22b494b6d69b4316e303f5932516.zip#egg=bleurt in /usr/local/lib/python3.7/dist-packages (from lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.0.2)
# Requirement already satisfied: pycountry==20.7.3 in /usr/local/lib/python3.7/dist-packages (from lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (20.7.3)
# Requirement already satisfied: numexpr==2.7.2 in /usr/local/lib/python3.7/dist-packages (from lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (2.7.2)
# Requirement already satisfied: pytest==6.2.3 in /usr/local/lib/python3.7/dist-packages (from lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (6.2.3)
# Requirement already satisfied: pybind11==2.6.2 in /usr/local/lib/python3.7/dist-packages (from lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (2.6.2)
# Requirement already satisfied: tqdm-multiprocess==0.0.11 in /usr/local/lib/python3.7/dist-packages (from lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.0.11)
# Requirement already satisfied: zstandard==0.15.2 in /usr/local/lib/python3.7/dist-packages (from lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.15.2)
# Requirement already satisfied: jsonlines==2.0.0 in /usr/local/lib/python3.7/dist-packages (from lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (2.0.0)
# Requirement already satisfied: mock==4.0.3 in /usr/local/lib/python3.7/dist-packages (from lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (4.0.3)
# Requirement already satisfied: openai==0.6.4 in /usr/local/lib/python3.7/dist-packages (from lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.6.4)
# Requirement already satisfied: jieba==0.42.1 in /usr/local/lib/python3.7/dist-packages (from lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.42.1)
# Requirement already satisfied: nagisa==0.2.7 in /usr/local/lib/python3.7/dist-packages (from lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.2.7)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.11.2->-r mesh-transformer-jax/requirements.txt (line 3)) (5.4.8)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.11.2->-r mesh-transformer-jax/requirements.txt (line 3)) (1.5.6)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.11.2->-r mesh-transformer-jax/requirements.txt (line 3)) (1.15.0)
# Requirement already satisfied: shortuuid>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.11.2->-r mesh-transformer-jax/requirements.txt (line 3)) (1.0.8)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.11.2->-r mesh-transformer-jax/requirements.txt (line 3)) (0.4.0)
# Requirement already satisfied: pathtools in /usr/local/lib/python3.7/dist-packages (from wandb>=0.11.2->-r mesh-transformer-jax/requirements.txt (line 3)) (0.1.2)
# Requirement already satisfied: GitPython>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.11.2->-r mesh-transformer-jax/requirements.txt (line 3)) (3.1.27)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.11.2->-r mesh-transformer-jax/requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.11.2->-r mesh-transformer-jax/requirements.txt (line 3)) (2.3)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.11.2->-r mesh-transformer-jax/requirements.txt (line 3)) (3.17.3)
# Requirement already satisfied: yaspin>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb>=0.11.2->-r mesh-transformer-jax/requirements.txt (line 3)) (2.1.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb>=0.11.2->-r mesh-transformer-jax/requirements.txt (line 3)) (3.13)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests~=2.25.1->-r mesh-transformer-jax/requirements.txt (line 5)) (2021.10.8)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests~=2.25.1->-r mesh-transformer-jax/requirements.txt (line 5)) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests~=2.25.1->-r mesh-transformer-jax/requirements.txt (line 5)) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests~=2.25.1->-r mesh-transformer-jax/requirements.txt (line 5)) (1.24.3)
# Requirement already satisfied: invoke<2.0,>=1.3 in /usr/local/lib/python3.7/dist-packages (from fabric~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 6)) (1.6.0)
# Requirement already satisfied: pathlib2 in /usr/local/lib/python3.7/dist-packages (from fabric~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 6)) (2.3.7.post1)
# Requirement already satisfied: paramiko>=2.4 in /usr/local/lib/python3.7/dist-packages (from fabric~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 6)) (2.9.2)
# Requirement already satisfied: absl-py>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from optax==0.0.9->-r mesh-transformer-jax/requirements.txt (line 7)) (0.15.0)
# Requirement already satisfied: chex>=0.0.4 in /usr/local/lib/python3.7/dist-packages (from optax==0.0.9->-r mesh-transformer-jax/requirements.txt (line 7)) (0.1.1)
# Requirement already satisfied: jaxlib>=0.1.37 in /usr/local/lib/python3.7/dist-packages (from optax==0.0.9->-r mesh-transformer-jax/requirements.txt (line 7)) (0.1.71+cuda111)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from dm-haiku==0.0.5->-r mesh-transformer-jax/requirements.txt (line 8)) (0.8.9)
# Requirement already satisfied: jmp>=0.0.2 in /usr/local/lib/python3.7/dist-packages (from dm-haiku==0.0.5->-r mesh-transformer-jax/requirements.txt (line 8)) (0.0.2)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from dm-haiku==0.0.5->-r mesh-transformer-jax/requirements.txt (line 8)) (3.7.4.3)
# Requirement already satisfied: opencensus in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (0.8.0)
# Requirement already satisfied: prometheus-client>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (0.13.1)
# Requirement already satisfied: grpcio>=1.28.1 in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (1.34.1)
# Requirement already satisfied: colorama in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (0.4.4)
# Requirement already satisfied: redis>=3.5.0 in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (4.1.4)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (1.0.3)
# Requirement already satisfied: aiohttp-cors in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (0.7.0)
# Requirement already satisfied: aioredis in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (2.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (3.6.0)
# Requirement already satisfied: gpustat in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (0.6.0)
# Requirement already satisfied: py-spy>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (0.3.11)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (3.8.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (4.3.3)
# Requirement already satisfied: pydantic>=1.8 in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (1.9.0)
# Requirement already satisfied: colorful; extra == "default" in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (0.5.4)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.7/dist-packages (from jax~=0.2.12->-r mesh-transformer-jax/requirements.txt (line 11)) (3.3.0)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask~=1.1.2->-r mesh-transformer-jax/requirements.txt (line 12)) (1.1.0)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask~=1.1.2->-r mesh-transformer-jax/requirements.txt (line 12)) (1.0.1)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask~=1.1.2->-r mesh-transformer-jax/requirements.txt (line 12)) (2.11.3)
# Requirement already satisfied: tensorboard<2.7,>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (2.6.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (1.12)
# Collecting tensorflow-estimator<2.7,>=2.6.0
#   Using cached tensorflow_estimator-2.6.0-py2.py3-none-any.whl (462 kB)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (1.1.2)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (1.12.1)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (3.1.0)
# Requirement already satisfied: keras<2.7,>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (2.6.0)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (0.2.0)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (0.37.1)
# Requirement already satisfied: clang~=5.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (5.0)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (1.6.3)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (0.4.0)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (1.1.0)
# Requirement already satisfied: google-cloud-core<2.0dev,>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage~=1.36.2->-r mesh-transformer-jax/requirements.txt (line 15)) (1.7.2)
# Requirement already satisfied: google-auth<2.0dev,>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage~=1.36.2->-r mesh-transformer-jax/requirements.txt (line 15)) (1.35.0)
# Requirement already satisfied: google-resumable-media<2.0dev,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from google-cloud-storage~=1.36.2->-r mesh-transformer-jax/requirements.txt (line 15)) (1.3.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers->-r mesh-transformer-jax/requirements.txt (line 16)) (21.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers->-r mesh-transformer-jax/requirements.txt (line 16)) (0.4.0)
# Requirement already satisfied: tokenizers!=0.11.3,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers->-r mesh-transformer-jax/requirements.txt (line 16)) (0.11.5)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers->-r mesh-transformer-jax/requirements.txt (line 16)) (2019.12.20)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers->-r mesh-transformer-jax/requirements.txt (line 16)) (4.11.1)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers->-r mesh-transformer-jax/requirements.txt (line 16)) (0.0.47)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.7/dist-packages (from ftfy->-r mesh-transformer-jax/requirements.txt (line 19)) (0.2.5)
# Requirement already satisfied: starlette==0.17.1 in /usr/local/lib/python3.7/dist-packages (from fastapi->-r mesh-transformer-jax/requirements.txt (line 20)) (0.17.1)
# Requirement already satisfied: asgiref>=3.4.0 in /usr/local/lib/python3.7/dist-packages (from uvicorn->-r mesh-transformer-jax/requirements.txt (line 21)) (3.5.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.7/dist-packages (from uvicorn->-r mesh-transformer-jax/requirements.txt (line 21)) (0.13.0)
# Requirement already satisfied: ujson in /usr/local/lib/python3.7/dist-packages (from lm_dataformat->-r mesh-transformer-jax/requirements.txt (line 22)) (5.1.0)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from pathy->-r mesh-transformer-jax/requirements.txt (line 23)) (0.4.0)
# Requirement already satisfied: pathspec>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from black->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.9.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from black->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (2.0.1)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.7/dist-packages (from black->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (2.5.1)
# Requirement already satisfied: typed-ast>=1.4.2; python_version < "3.8" and implementation_name == "cpython" in /usr/local/lib/python3.7/dist-packages (from black->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.5.2)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/lib/python3.7/dist-packages (from black->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.4.3)
# Requirement already satisfied: rehash in /usr/local/lib/python3.7/dist-packages (from best_download==0.0.9->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.0.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets==1.15.1->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.3.5)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets==1.15.1->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.3.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from datasets==1.15.1->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (3.0.0)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from datasets==1.15.1->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (2022.2.0)
# Requirement already satisfied: pyarrow!=4.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets==1.15.1->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (6.0.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets==1.15.1->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.70.12.2)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24.1->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24.1->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.24.1->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (3.1.0)
# Requirement already satisfied: pathvalidate<3,>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from pytablewriter==0.58.0->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (2.5.0)
# Requirement already satisfied: DataProperty<2,>=0.50.0 in /usr/local/lib/python3.7/dist-packages (from pytablewriter==0.58.0->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.54.2)
# Requirement already satisfied: typepy[datetime]<2,>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from pytablewriter==0.58.0->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: tabledata<2,>=1.1.3 in /usr/local/lib/python3.7/dist-packages (from pytablewriter==0.58.0->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: mbstrdecoder<2,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from pytablewriter==0.58.0->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.1.0)
# Requirement already satisfied: setuptools>=38.3.0 in /usr/local/lib/python3.7/dist-packages (from pytablewriter==0.58.0->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (57.4.0)
# Requirement already satisfied: msgfy<1,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from pytablewriter==0.58.0->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.2.0)
# Requirement already satisfied: tcolorpy<1,>=0.0.5 in /usr/local/lib/python3.7/dist-packages (from pytablewriter==0.58.0->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.1.1)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.7/dist-packages (from sacrebleu==1.5.0->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (2.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from rouge-score==0.0.4->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (3.2.5)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from bleurt@ https://github.com/google-research/bleurt/archive/b610120347ef22b494b6d69b4316e303f5932516.zip#egg=bleurt->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.1.96)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (from bleurt@ https://github.com/google-research/bleurt/archive/b610120347ef22b494b6d69b4316e303f5932516.zip#egg=bleurt->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (2.5.0)
# Requirement already satisfied: tf-slim>=1.1 in /usr/local/lib/python3.7/dist-packages (from bleurt@ https://github.com/google-research/bleurt/archive/b610120347ef22b494b6d69b4316e303f5932516.zip#egg=bleurt->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.1.0)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.7/dist-packages (from pytest==6.2.3->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.1.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from pytest==6.2.3->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (21.4.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from pytest==6.2.3->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.10.2)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in /usr/local/lib/python3.7/dist-packages (from pytest==6.2.3->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.13.1)
# Requirement already satisfied: py>=1.8.2 in /usr/local/lib/python3.7/dist-packages (from pytest==6.2.3->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (1.11.0)
# Requirement already satisfied: DyNet in /usr/local/lib/python3.7/dist-packages (from nagisa==0.2.7->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (2.1.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb>=0.11.2->-r mesh-transformer-jax/requirements.txt (line 3)) (4.0.9)
# Requirement already satisfied: pynacl>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from paramiko>=2.4->fabric~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 6)) (1.5.0)
# Requirement already satisfied: cryptography>=2.5 in /usr/local/lib/python3.7/dist-packages (from paramiko>=2.4->fabric~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 6)) (36.0.1)
# Requirement already satisfied: bcrypt>=3.1.3 in /usr/local/lib/python3.7/dist-packages (from paramiko>=2.4->fabric~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 6)) (3.2.0)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from chex>=0.0.4->optax==0.0.9->-r mesh-transformer-jax/requirements.txt (line 7)) (0.11.2)
# Requirement already satisfied: dm-tree>=0.1.5 in /usr/local/lib/python3.7/dist-packages (from chex>=0.0.4->optax==0.0.9->-r mesh-transformer-jax/requirements.txt (line 7)) (0.1.6)
# Requirement already satisfied: opencensus-context==0.1.2 in /usr/local/lib/python3.7/dist-packages (from opencensus->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (0.1.2)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from opencensus->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (1.26.3)
# Requirement already satisfied: deprecated>=1.2.3 in /usr/local/lib/python3.7/dist-packages (from redis>=3.5.0->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (1.2.13)
# Requirement already satisfied: async-timeout in /usr/local/lib/python3.7/dist-packages (from aioredis->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (4.0.2)
# Requirement already satisfied: nvidia-ml-py3>=7.352.0 in /usr/local/lib/python3.7/dist-packages (from gpustat->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (7.352.0)
# Requirement already satisfied: blessings>=1.6 in /usr/local/lib/python3.7/dist-packages (from gpustat->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (1.7)
# Requirement already satisfied: asynctest==0.13.0; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (0.13.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (1.7.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (1.2.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (6.0.2)
# Requirement already satisfied: importlib-resources>=1.4.0; python_version < "3.9" in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (5.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (0.18.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask~=1.1.2->-r mesh-transformer-jax/requirements.txt (line 12)) (2.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (3.3.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.7,>=2.6.0->tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (1.8.1)
# Requirement already satisfied: cached-property; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from h5py~=3.1.0->tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (1.5.2)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage~=1.36.2->-r mesh-transformer-jax/requirements.txt (line 15)) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage~=1.36.2->-r mesh-transformer-jax/requirements.txt (line 15)) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.11.0->google-cloud-storage~=1.36.2->-r mesh-transformer-jax/requirements.txt (line 15)) (4.2.4)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0; python_version >= "3.5" in /usr/local/lib/python3.7/dist-packages (from google-resumable-media<2.0dev,>=1.2.0->google-cloud-storage~=1.36.2->-r mesh-transformer-jax/requirements.txt (line 15)) (1.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers->-r mesh-transformer-jax/requirements.txt (line 16)) (3.0.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers->-r mesh-transformer-jax/requirements.txt (line 16)) (3.7.0)
# Requirement already satisfied: anyio<4,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from starlette==0.17.1->fastapi->-r mesh-transformer-jax/requirements.txt (line 20)) (3.5.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets==1.15.1->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (2018.9)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in /usr/local/lib/python3.7/dist-packages (from tensorflow->bleurt@ https://github.com/google-research/bleurt/archive/b610120347ef22b494b6d69b4316e303f5932516.zip#egg=bleurt->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (2.5.0.dev2021032900)
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from DyNet->nagisa==0.2.7->lm-eval==0.1.0->-r mesh-transformer-jax/requirements.txt (line 9)) (0.29.28)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb>=0.11.2->-r mesh-transformer-jax/requirements.txt (line 3)) (5.0.0)
# Requirement already satisfied: cffi>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from pynacl>=1.0.1->paramiko>=2.4->fabric~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 6)) (1.15.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3.0.0,>=1.0.0; python_version >= "3.6"->opencensus->ray[default]==1.4.1->-r mesh-transformer-jax/requirements.txt (line 10)) (1.54.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.7,>=2.6.0->tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (1.3.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2.0dev,>=1.11.0->google-cloud-storage~=1.36.2->-r mesh-transformer-jax/requirements.txt (line 15)) (0.4.8)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.7/dist-packages (from anyio<4,>=3.0.0->starlette==0.17.1->fastapi->-r mesh-transformer-jax/requirements.txt (line 20)) (1.2.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.4.1->pynacl>=1.0.1->paramiko>=2.4->fabric~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 6)) (2.21)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.7,>=2.6.0->tensorflow-cpu~=2.6.0->-r mesh-transformer-jax/requirements.txt (line 14)) (3.2.0)
# Building wheels for collected packages: lm-eval
#   Building wheel for lm-eval (setup.py) ... done
#   Created wheel for lm-eval: filename=lm_eval-0.1.0-py3-none-any.whl size=120672 sha256=381969871a1812046fa9dcc90146aaa964d3056cd8a8765987fdb4e47738d1a3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0uzp58is/wheels/35/22/ec/71da337686fde904ec27f675d1bf73c4f253c48a6174d822b0
# Successfully built lm-eval
# Installing collected packages: tensorflow-estimator
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.5.0
#     Uninstalling tensorflow-estimator-2.5.0:
#       Successfully uninstalled tensorflow-estimator-2.5.0
# ERROR: pip's legacy dependency resolver does not consider dependency conflicts when selecting packages. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.5.0 requires tensorflow-estimator<2.6.0,>=2.5.0rc0, but you'll have tensorflow-estimator 2.6.0 which is incompatible.
# tensorflow-cpu 2.6.3 requires grpcio<2.0,>=1.37.0, but you'll have grpcio 1.34.1 which is incompatible.
# Successfully installed tensorflow-estimator-2.6.0
# Processing ./mesh-transformer-jax
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# Requirement already satisfied: jax==0.2.12 in /usr/local/lib/python3.7/dist-packages (0.2.12)
# Requirement already satisfied: tensorflow==2.5.0 in /usr/local/lib/python3.7/dist-packages (2.5.0)
# Requirement already satisfied: numpy>=1.12 in /usr/local/lib/python3.7/dist-packages (from jax==0.2.12) (1.19.5)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from jax==0.2.12) (0.15.0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.7/dist-packages (from jax==0.2.12) (3.3.0)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (3.1.0)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (1.6.3)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (1.1.0)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (1.12.1)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (1.12)
# Collecting tensorflow-estimator<2.6.0,>=2.5.0rc0
#   Using cached tensorflow_estimator-2.5.0-py2.py3-none-any.whl (462 kB)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (0.37.1)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (2.5.0.dev2021032900)
# Requirement already satisfied: tensorboard~=2.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (2.6.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (3.17.3)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (1.1.2)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (3.7.4.3)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (1.15.0)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (0.2.0)
# Requirement already satisfied: grpcio~=1.34.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (1.34.1)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.5.0) (0.4.0)
# Requirement already satisfied: cached-property; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from h5py~=3.1.0->tensorflow==2.5.0) (1.5.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5.0) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5.0) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5.0) (0.6.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5.0) (1.35.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5.0) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5.0) (3.3.6)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5.0) (57.4.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow==2.5.0) (2.25.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.0) (1.3.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0) (4.2.4)
# Requirement already satisfied: importlib-metadata>=4.4; python_version < "3.10" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow==2.5.0) (4.11.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow==2.5.0) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow==2.5.0) (3.2.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow==2.5.0) (0.4.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4; python_version < "3.10"->markdown>=2.6.8->tensorboard~=2.5->tensorflow==2.5.0) (3.7.0)
# Building wheels for collected packages: mesh-transformer
#   Building wheel for mesh-transformer (setup.py) ... done
#   Created wheel for mesh-transformer: filename=mesh_transformer-0.0.0-py3-none-any.whl size=26330 sha256=5fafeac11787841416b44a7f7b845adc01cfcb5c09b96c87be10bf779f566f23
#   Stored in directory: /root/.cache/pip/wheels/56/bd/89/b1f6b2f3d6b938d0c5812ee97756a1afd32521bea293543863
# Successfully built mesh-transformer
# Installing collected packages: mesh-transformer, tensorflow-estimator
#   Attempting uninstall: mesh-transformer
#     Found existing installation: mesh-transformer 0.0.0
#     Uninstalling mesh-transformer-0.0.0:
#       Successfully uninstalled mesh-transformer-0.0.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.6.0
#     Uninstalling tensorflow-estimator-2.6.0:
#       Successfully uninstalled tensorflow-estimator-2.6.0
# ERROR: pip's legacy dependency resolver does not consider dependency conflicts when selecting packages. This behaviour is the source of the following dependency conflicts.
# tensorflow-cpu 2.6.3 requires grpcio<2.0,>=1.37.0, but you'll have grpcio 1.34.1 which is incompatible.
# tensorflow-cpu 2.6.3 requires tensorflow-estimator<2.7,>=2.6.0, but you'll have tensorflow-estimator 2.5.0 which is incompatible.
# Successfully installed mesh-transformer-0.0.0 tensorflow-estimator-2.5.0

# %% [markdown]
# ## Setup Model

# %%
import os
import requests 
from jax.config import config

colab_tpu_addr = os.environ['COLAB_TPU_ADDR'].split(':')[0]
url = f'http://{colab_tpu_addr}:8475/requestversion/tpu_driver0.1_dev20210607'
requests.post(url)

# The following is required to use TPU Driver as JAX's backend.
config.FLAGS.jax_xla_backend = "tpu_driver"
config.FLAGS.jax_backend_target = "grpc://" + os.environ['COLAB_TPU_ADDR']
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# Sometimes the next step errors for some reason, just run it again ¯\\\_(ツ)\_/¯

# %%
import time

import jax
from jax.experimental import maps
import numpy as np
import optax
import transformers

from mesh_transformer.checkpoint import read_ckpt_lowmem
from mesh_transformer.sampling import nucleaus_sample
from mesh_transformer.transformer_shard import CausalTransformer
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %%
params = {
  "layers": 28,
  "d_model": 4096,
  "n_heads": 16,
  "n_vocab": 50400,
  "norm": "layernorm",
  "pe": "rotary",
  "pe_rotary_dims": 64,

  "seq": 2048,
  "cores_per_replica": 8,
  "per_replica_batch": 1,
}

per_replica_batch = params["per_replica_batch"]
cores_per_replica = params["cores_per_replica"]
seq = params["seq"]


params["sampler"] = nucleaus_sample

# here we "remove" the optimizer parameters from the model (as we don't need them for inference)
params["optimizer"] = optax.scale(0)

mesh_shape = (jax.device_count() // cores_per_replica, cores_per_replica)
devices = np.array(jax.devices()).reshape(mesh_shape)

maps.thread_resources.env = maps.ResourceEnv(maps.Mesh(devices, ('dp', 'mp')))

tokenizer = transformers.GPT2TokenizerFast.from_pretrained('gpt2')
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>

# %% [markdown]
# Here we create the network and load the parameters from the downloaded files. Expect this to take around 5 minutes.

# %%
total_batch = per_replica_batch * jax.device_count() // cores_per_replica

network = CausalTransformer(params)

network.state = read_ckpt_lowmem(network.state, "step_383500/", devices.shape[1])

network.state = network.move_xmap(network.state, np.zeros(cores_per_replica))
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# /usr/local/lib/python3.7/dist-packages/jax/experimental/maps.py:412: UserWarning: xmap is an experimental feature and probably has bugs!
#   warn("xmap is an experimental feature and probably has bugs!")
# key shape (8, 2)
# in shape (1, 2048)
# dp 1
# mp 8
# Total parameters: 6053381344
# read from disk/gcs in 163.631s

# %% [markdown]
# ## Run Model
#
# Finally, we are ready to infer with the model! The first sample takes around a minute due to compilation, but after that it should only take about 10 seconds per sample.
#
# Feel free to mess with the different sampling parameters (top_p and temp), as well as the length of the generations (gen_len, causes a recompile when changed).
#
# You can also change other things like per_replica_batch in the previous cells to change how many generations are done in parallel. A larger batch has higher latency but higher throughput when measured in tokens generated/s. This is useful for doing things like best-of-n cherry picking.
#
# *Tip for best results: Make sure your prompt does not have any trailing spaces, which tend to confuse the model due to the BPE tokenization used during training.*

# %%
# allow text wrapping in generated output: https://stackoverflow.com/a/61401455
from IPython.display import HTML, display

def set_css():
  display(HTML('''
  <style>
    pre {
        white-space: pre-wrap;
    }
  </style>
  '''))
get_ipython().events.register('pre_run_cell', set_css)

# %%
# !pip install tensorflow==1.15
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# Collecting tensorflow==1.15
#   Downloading tensorflow-1.15.0-cp37-cp37m-manylinux2010_x86_64.whl (412.3 MB)
#      |████████████████████████████████| 412.3 MB 21 kB/s
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (1.1.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (1.34.1)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (0.15.0)
# Collecting tensorboard<1.16.0,>=1.15.0
#   Downloading tensorboard-1.15.0-py3-none-any.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 61.7 MB/s
# Collecting gast==0.2.2
#   Downloading gast-0.2.2.tar.gz (10 kB)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (3.17.3)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (1.19.5)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (0.8.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (3.3.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (1.1.2)
# Collecting tensorflow-estimator==1.15.1
#   Downloading tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503 kB)
#      |████████████████████████████████| 503 kB 63.1 MB/s
# Collecting keras-applications>=1.0.8
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 6.9 MB/s
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (0.37.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (1.15.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (1.12.1)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15) (0.2.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->tensorflow==1.15) (3.1.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (3.3.6)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (57.4.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (1.0.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (4.11.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15) (3.7.4.3)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.8->tensorflow==1.15) (1.5.2)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7554 sha256=2f30d72335299990af0b7c5ef1f7df110197dd8127466745bcd5b9bf4366e035
#   Stored in directory: /root/.cache/pip/wheels/21/7f/02/420f32a803f7d0967b48dd823da3f558c5166991bfd204eef3
# Successfully built gast
# Installing collected packages: tensorflow-estimator, tensorboard, keras-applications, gast, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.5.0
#     Uninstalling tensorflow-estimator-2.5.0:
#       Successfully uninstalled tensorflow-estimator-2.5.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.6.0
#     Uninstalling tensorboard-2.6.0:
#       Successfully uninstalled tensorboard-2.6.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.4.0
#     Uninstalling gast-0.4.0:
#       Successfully uninstalled gast-0.4.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.5.0
#     Uninstalling tensorflow-2.5.0:
#       Successfully uninstalled tensorflow-2.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-probability 0.16.0 requires gast>=0.3.2, but you have gast 0.2.2 which is incompatible.
# tensorflow-cpu 2.6.3 requires gast==0.4.0, but you have gast 0.2.2 which is incompatible.
# tensorflow-cpu 2.6.3 requires grpcio<2.0,>=1.37.0, but you have grpcio 1.34.1 which is incompatible.
# tensorflow-cpu 2.6.3 requires tensorboard<2.7,>=2.6.0, but you have tensorboard 1.15.0 which is incompatible.
# tensorflow-cpu 2.6.3 requires tensorflow-estimator<2.7,>=2.6.0, but you have tensorflow-estimator 1.15.1 which is incompatible.
# kapre 0.3.7 requires tensorflow>=2.0.0, but you have tensorflow 1.15.0 which is incompatible.
# Successfully installed gast-0.2.2 keras-applications-1.0.8 tensorboard-1.15.0 tensorflow-1.15.0 tensorflow-estimator-1.15.1

# %%
def infer(context, top_p=0.9, temp=1.0, gen_len=512):
    tokens = tokenizer.encode(context)

    provided_ctx = len(tokens)
    pad_amount = seq - provided_ctx

    padded_tokens = np.pad(tokens, ((pad_amount, 0),)).astype(np.uint32)
    batched_tokens = np.array([padded_tokens] * total_batch)
    length = np.ones(total_batch, dtype=np.uint32) * len(tokens)

    start = time.time()
    output = network.generate(batched_tokens, length, gen_len, {"top_p": np.ones(total_batch) * top_p, "temp": np.ones(total_batch) * temp})

    samples = []
    decoded_tokens = output[1][0]

    for o in decoded_tokens[:, :, 0]:
      samples.append(f"\033[1m{context}\033[0m{tokenizer.decode(o)}")

    print(f"completion done in {time.time() - start:06}s")
    return samples

print(infer("EleutherAI is")[0])
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# completion done in 56.36220908164978s
# EleutherAI is a self-administered Altcoin exchange. It provides security and personal services through SMS, games, verification, and search. It acts as a community-based Altcoin exchange that provides individuals with the power of a decentralized and secure platform. We have high level security measures in place for exchanging Altcoins.
#
# View all posts by Eduard Blum
#
# Get all the latest news, lessons, and videos for FREE!
#
# Profit Acai Coupon
#
# $5 OFF 300
#
# “Success of the Community Is Proven:” Success at Atomico Level – Just Launched on Mainnet
#
# Today, we are launching an ETH-based Crowdsale for Enlitic, a next generation crypto token that will help users monetize their online presence. We are going to bring a company by the name “Nuggets” to the Ethereum Mainnet, helping blockchain users become truly decentralized and profitable through the utilization of Enlitic’s platform.
#
# Enlitic will revolutionize how people manage their online identity. Most of us have a web presence, that often includes a social media profile, a website, a blog, or maybe even a mailing list or a forum. And we also have an offline presence, including our phone number, mailing address, business card, and so on. Today, our online presence is almost always associated with a centralized identity, and is controlled by companies that are not responsible to the public. They use our information without our permission, and for the most part we can’t even know how they are using it.
#
# A year ago, the team behind Enlitic wanted to create a decentralized identity protocol, so they invented Enlitic, a protocol that is designed to allow anyone to create a profile, or an online presence, and keep control over it. Then they designed a wallet for Enlitic tokens, which could be used to interact with other users, post on forums and blogs, find friends on the internet, etc. Now, Enlitic is ready to launch, and we are proud to be able to bring it to the Ethereum Mainnet.
#
# “Success of the Community Is Proven:”
#
# I first became involved in crypto back in early 2011, long before I even had any experience in tech, marketing, or management. The idea of a decentralized identity management system sounded so exciting to me that I joined up with two of my best friends to start a project that we dubbed “Enl

# %%
#@title  { form-width: "300px" }
top_p = 0.9 #@param {type:"slider", min:0, max:1, step:0.1}
temp = 1 #@param {type:"slider", min:0, max:1, step:0.1}

context = """The capital of Morocco is Rabat"""

print(infer(top_p=top_p, temp=temp, gen_len=512, context=context)[0])
# Out:
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
# completion done in 13.523292541503906s
# The capital of Morocco is Rabat. Its largest city is Casablanca. Its currency is the Moroccan Dirham.
#
# The currency of Morocco is the Moroccan Dirham. It was introduced on August 17, 1956 and replaced the Franc Marocain at a rate of 4.5 Dirhams = one Franc Marocain. Dirhams are divided into 100 Centimes. Coins are copper-nickel and 10 and 20 centimes; and 5 and 1 dirham. Banknotes are similar, but of the same size and colour.
#
# Rabat, Casablanca, and Casa-Blanca are three famous names which come from the old Arabic names for the capital. The best known of these is probably Casablanca, named for a fortified Phoenician trading centre. It is linked with a string of folkloric names: Morisset, Seville, Mouza, Al Mozzaz, Guelghem, Bentzem, Mendibid, Gafsa, Oujda, Sus etc. The word Casa-Blanca, which refers to an Irish whiskey, seems to be a local appellation for a style of whisky, produced in Tangier.
#
# The name of the currency is based on that of the currency of the European world at the time when Morocco was created. In Europe in those days, there were also modern currencies, such as the Swiss Franc, the Belgian Franc, and the French Franc. But these were less popular than the German and Austrian currency, so as a standard was adopted, it was the Deutsche Mark which was chosen, even though Germany was less than five years old at the time. It is not surprising that this name was then applied to the new currency.
#
# The original one hundred dirham notes were printed in an unusual manner.
#
# At the time the first series of paper money was being issued, the entire old banknotes of Morocco were destroyed, without any particular reason, thus creating a serious problem for users. As a result, some old notes were still in circulation, although very slowly and on the face of it were badly printed. The 100 dirham notes were overprinted with a date when the new currency was introduced.
#
# To give the state authority, Morocco had to receive the members of the Universal Postal Union and the United Nations Postal Organization. To this end, a special Postal Charter was signed in 1961. Since then, the Moroccan Post has been divided into four provinces: Morocco, Fes, Meknes and Tanger-Tetou
